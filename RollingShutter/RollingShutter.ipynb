# %%
import numpy as np
import seaborn as sns
from IPython.display import HTML , display
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.spatial import distance_matrix
from skimage import io
from tqdm import tqdm as progress_bar

# %%
M = 32 # sequence
propellars_number = 3 # number of propellars
m_values = np.arange(-M //2 , M //2)

# %%
def propellar_sim(alfa,m):
    return np.sin(propellars_number*alfa + m*np.pi/10) #mathematical formula from PDF
alfa = np.linspace(-np.pi,np.pi,1000)
isim = propellar_sim(alfa,m=5)
figure = plt.figure(figsize=[8, 8])
plt.polar(alfa,isim)

# %%
def polar_to_cartesian(alfa,r):
    x = r * np.cos(alfa)
    y = r * np.sin(alfa)
    return np.column_stack([x,y])

# %%
def capture(function: np.array, resolution: int, threshold: float = 0.1, low: float = -1, high: float = 1):
    x_line, y_column = np.meshgrid(np.linspace(low,high,resolution), np.linspace(low,high,resolution))
    grid = np.column_stack([x_line.flatten(), y_column.flatten()])
    distances = distance_matrix(grid, function)
    catch = (np.min(distances, axis = 1) <= threshold).astype(int).reshape(resolution,resolution)
    return catch

# %%
plt.imshow(capture(polar_to_cartesian(alfa, isim), resolution=256, threshold=0.05, low=-np.pi / 2, high=np.pi / 2))

# %%
funcs = []
for m in m_values.tolist():
    r = propellar_sim(alfa,m=m)
    func = polar_to_cartesian(alfa,r)
    funcs.append(func)
funcs = np.asarray(funcs)
# Out:
# [9.51056516e-01 1.16470832e-16]

# %%
def recording(funcs: list, capture_kwargs):
    return np.asarray([capture(func, **capture_kwargs) for func in progress_bar(funcs)])

# %%
record = recording(funcs, capture_kwargs=dict(resolution = 256, threshold = 0.05, low = -np.pi /2 , high = np.pi/2))
record.shape
# Out:
#  50%|█████     | 16/32 [01:03<01:03,  3.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Macie\OneDrive\Dokumenty\GitHub\git\Sygnaly-i-obrazy-cyfrowe\10.10.2023\RollingShutter.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> record = recording(funcs, capture_kwargs=dict(resolution = 256, threshold = 0.05, low = -np.pi /2 , high = np.pi/2))
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> record.shape
#
# c:\Users\Macie\OneDrive\Dokumenty\GitHub\git\Sygnaly-i-obrazy-cyfrowe\10.10.2023\RollingShutter.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> def recording(funcs: list, capture_kwargs):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     return np.asarray([capture(func, **capture_kwargs) for func in progress_bar(funcs)])
#
# c:\Users\Macie\OneDrive\Dokumenty\GitHub\git\Sygnaly-i-obrazy-cyfrowe\10.10.2023\RollingShutter.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> def recording(funcs: list, capture_kwargs):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     return np.asarray([capture(func, **capture_kwargs) for func in progress_bar(funcs)])
#
# c:\Users\Macie\OneDrive\Dokumenty\GitHub\git\Sygnaly-i-obrazy-cyfrowe\10.10.2023\RollingShutter.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> x_line, y_column = np.meshgrid(np.linspace(low,high,resolution), np.linspace(low,high,resolution))
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> grid = np.column_stack([x_line.flatten(), y_column.flatten()])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> distances = distance_matrix(grid, function)
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> catch = (np.min(distances, axis = 1) <= threshold).astype(int).reshape(resolution,resolution)
#       <a href='vscode-notebook-cell:/c%3A/Users/Macie/OneDrive/Dokumenty/GitHub/git/Sygnaly-i-obrazy-cyfrowe/10.10.2023/RollingShutter.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> return catch
#
# File c:\Users\Macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\spatial\_kdtree.py:919, in distance_matrix(x, y, p, threshold)
#     917 else:
#     918     for j in range(n):
# --> 919         result[:,j] = minkowski_distance(x,y[j],p)
#     920 return result
#
# File c:\Users\Macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\spatial\_kdtree.py:95, in minkowski_distance(x, y, p)
#      93     return minkowski_distance_p(x, y, p)
#      94 else:
# ---> 95     return minkowski_distance_p(x, y, p)**(1./p)
#
# File c:\Users\Macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\spatial\_kdtree.py:60, in minkowski_distance_p(x, y, p)
#      58     return np.sum(np.abs(y-x), axis=-1)
#      59 else:
# ---> 60     return np.sum(np.abs(y-x)**p, axis=-1)
#
# File c:\Users\Macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:2172, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2102     """
#    2103     Clip (limit) the values in an array.
#    2104
#    (...)
#    2167
#    2168     """
#    2169     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2172 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2173                     initial=None, where=None):
#    2174     return (a, out)
#    2177 @array_function_dispatch(_sum_dispatcher)
#    2178 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2179         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
offset = 0
length = 8
capture = np.zeros([256,256])

for frame in record:
    capture[offset: offset + length, :] = frame[offset: offset + length,:]
    offset += length

# %%
plt.imshow(capture, cmap="Greys")
